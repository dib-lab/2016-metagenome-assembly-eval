# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib.pyplot import *

# %%
contigs =[0, 250, 500, 750, 1000, 2000]

# %%
vqc_total_length =[164397578,163112466,159537740,157220913,155353536,150138485]
iqc_total_length =[200962385,200939945,198818587,196690925,194798561,187611489] 
sqc_total_length =[200742793,200278128,197107341,194752614,192502691,185123456] 
mqc_total_length =[211681265,207364425,198360585,194746275,191920652,181756001]

vdigi_total_length =[199555556,198846827,195279331,192038284,188890498,177431362]
idigi_total_length =[200083762,200077044,198761297,197216607,195779746,189654321] 
sdigi_total_length =[199687122,199237470,196464077,194268249,192161263,184671409] 
mdigi_total_length =[200453745,199751604,196439431,193426523,190351416,178977333]

vpart_total_length =[200493635,199705369,195705327,191771131,187804091,17191595]
ipart_total_length =[198313218,198308366,196691548,194572523,192478143,183804257] 
spart_total_length =[198001012,197620842,194563093,191721976,188937831,178783394] 
mpart_total_length =[198456118,197523063,193904476,190409162,186806671,173718716]

# %%
tl_vqc= plt.plot(contigs, vqc_total_length,color='r', linestyle='solid', linewidth=3, label ='Velvet QC', marker ="*")
plt.legend(vqc_total_length, "Velvet QC", 'best')

tl_iqc= plt.plot(contigs, iqc_total_length,color='b', linestyle='solid', linewidth=3, label ='IDBA QC', marker ="*")
plt.legend(iqc_total_length, "IDBA QC", 'best')

tl_sqc= plt.plot(contigs, sqc_total_length,color='#FFA500', linestyle='solid', linewidth=3, label ='SPAdes QC', marker ="*")
plt.legend(sqc_total_length, "SPAdes QC", 'best')

tl_mqc= plt.plot(contigs, mqc_total_length,color='g', linestyle='solid', linewidth=3, label ='Megahit QC', marker ="*")
plt.legend(mqc_total_length, "Megahit QC", 'best')
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 164397578
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 163112466
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 159537740
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 157220913
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 155353536
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 150138485
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 200962385
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 200939945
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 198818587
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 196690925
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 194798561
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 187611489
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 200742793
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 200278128
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 197107341
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 194752614
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 192502691
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 185123456
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 211681265
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 207364425
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 198360585
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 194746275
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 191920652
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 181756001
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))

# %%
tl_vdigi= plt.plot(contigs, vdigi_total_length,color='r', linestyle='solid', linewidth=3, label ='Velvet Diginorm', marker ="o")
plt.legend(vdigi_total_length, "Velvet Diginorm", 'best')

tl_idigi= plt.plot(contigs, idigi_total_length,color='b', linestyle='solid', linewidth=3, label ='IDBA Diginorm', marker ="o")
plt.legend(idigi_total_length, "IDBA Diginorm", 'best')

tl_sdigi= plt.plot(contigs, sdigi_total_length,color='#FFA500', linestyle='solid', linewidth=3, label ='SPAdes Diginorm', marker ="o")
plt.legend(sdigi_total_length, "SPAdes Diginorm", 'best')

tl_mdigi= plt.plot(contigs, mdigi_total_length,color='g', linestyle='solid', linewidth=3, label ='Megahit Diginorm', marker ="o")
plt.legend(mdigi_total_length, "Megahit Diginorm", 'best')
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 199555556
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 198846827
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 195279331
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 192038284
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 188890498
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 177431362
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 200083762
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 200077044
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 198761297
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 197216607
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 195779746
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 189654321
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 199687122
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 199237470
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 196464077
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 194268249
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 192161263
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 184671409
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 200453745
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 199751604
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 196439431
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 193426523
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 190351416
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 178977333
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))

# %%
tl_vpart= plt.plot(contigs, vpart_total_length,color='r', linestyle='solid', linewidth=3, label ='Velvet Partition', marker ="+")
plt.legend(vpart_total_length, "Velvet Partition", 'best')

tl_ipart= plt.plot(contigs, ipart_total_length,color='b', linestyle='solid', linewidth=3, label ='IDBA Partition', marker ="+")
plt.legend(ipart_total_length, "IDBA Partition", 'best')

tl_spart= plt.plot(contigs, spart_total_length,color='#FFA500', linestyle='solid', linewidth=3, label ='SPAdes Partition', marker ="+")
plt.legend(spart_total_length, "SPAdes Partition", 'best')

tl_mpart= plt.plot(contigs, mpart_total_length,color='g', linestyle='solid', linewidth=3, label ='Megahit Partition', marker ="+")
plt.legend(mpart_total_length, "Megahit Partition", 'best')
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 200493635
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 199705369
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 195705327
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 191771131
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 187804091
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 17191595
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 198313218
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 198308366
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 196691548
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 194572523
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 192478143
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 183804257
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 198001012
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 197620842
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 194563093
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 191721976
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 188937831
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 178783394
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 198456118
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 197523063
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 193904476
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 190409162
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 186806671
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/legend.py:613: UserWarning: Legend does not support 173718716
# Use proxy artist instead.
#
# http://matplotlib.sourceforge.net/users/legend_guide.html#using-proxy-artist
#
#   (str(orig_handle),))

# %%
plt.title('Assembly Total Length using Different Minimum Contigs Length')
plt.xlabel('Minimum Contig')
plt.ylabel('Assembly Total Length')
plt.legend(loc='center right', bbox_to_anchor=(0.85, 0.27),
          fancybox=True, shadow=True, ncol=2)
plt.show()
